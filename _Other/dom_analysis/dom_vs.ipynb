# %%
ACTIVATE_PRINTS = False

# %%
import pandas as pd
import numpy as n
import pickle
import os
from pathlib import Path

base_dir = Path(__file__).resolve().parent if "__file__" in globals() else Path.cwd()
data_path = (base_dir / "../_DataPreparation/dataPrepared.pkl").resolve()
with open(os.path.normpath(data_path), "rb") as f:
    data = pickle.load(f)

dataA = data['dataA']
dataC = data['dataC']
dataA_startID = data['dataA_startID']
dataA_endID = data['dataA_endID']
dataC_lastGoodID = data['dataC_lastGoodID']

dataA
# Out:
# [                                                caption      mean  precision  \
#  rank
#  0             I'm a congressman--obstruction is my job.  1.913043   0.094022
#  1     I'm what they mean when they say, 'The middle ...  1.842105   0.191381
#  2                     Does this suit make me look flat?  1.711111   0.112915
#  3       When the right woman comes along, I'll know it.  1.625000   0.116657
#  4     I used to lie in the gutter, but then I quit d...  1.617647   0.133610
#  ...                                                 ...       ...        ...
#  3900  Just getting material for my book, " Humanity ...  1.000000   0.117851
#  3901     This has 'Alice in Wonderland' beat by a mile.  1.000000   0.117851
#  3902                    I could use a quick pick-me-up.  1.000000   0.117851
#  3903     This is the secret to attracting foot traffic.  1.000000   0.117851
#  3904                 An aloof view of clouds colliding.  1.000000   0.117851
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0        69         24              27     18
#  1        19          8               6      5
#  2        45         21              16      8
#  3        32         15              14      3
#  4        34         19               9      6
#  ...     ...        ...             ...    ...
#  3900      9          9               0      0
#  3901      9          9               0      0
#  3902      9          9               0      0
#  3903      9          9               0      0
#  3904      9          9               0      0
#
#  [3905 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0                                           I'm hourly.  1.860465   0.127074
#  1     And one day your son will keep you from having...  1.794118   0.138617
#  2                  I wish you had found that yesterday.  1.741935   0.146410
#  3                Attention to detail is important, son.  1.703704   0.149213
#  4                           My cardiologist sells them.  1.692308   0.144320
#  ...                                                 ...       ...        ...
#  3320  This isn't what I meant when I switched the Ch...  1.000000   0.154303
#  3321  So are you that self ploughing plough from Goo...  1.000000   0.154303
#  3322           That's how we do it here in Gnome,Alaska  1.000000   0.154303
#  3323   Is your mother trying to give me a heart attack?  1.000000   0.154303
#  3324  Nothing is going to stop me from getting The N...  1.000000   0.154303
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0        43         18              13     12
#  1        34         15              11      8
#  2        31         15               9      7
#  3        27         13               9      5
#  4        26         12              10      4
#  ...     ...        ...             ...    ...
#  3320      7          7               0      0
#  3321      7          7               0      0
#  3322      7          7               0      0
#  3323      7          7               0      0
#  3324      7          7               0      0
#
#  [3325 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0                  We're pretentious, not ostentatious.  2.250000   0.168005
#  1                         Broga meets on the 2nd floor.  2.000000   0.241523
#  2                    Please put that back in reception.  1.900000   0.179505
#  3     I told you to bring your own, that's from our ...  1.857143   0.177192
#  4                                    Let her out, Fred.  1.846154   0.249259
#  ...                                                 ...       ...        ...
#  4394     Is she in your mat practicing the corpse pose?  1.000000   0.408248
#  4395                       beginning yoga is room five.  1.000000   0.408248
#  4396  You're supposed to leave your shoes and your e...  1.000000   0.288675
#  4397                   You can stretch the full length?  1.000000   0.223607
#  4398  We know you're shagedelic, but no one's impres...  1.000000   0.288675
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0        32         11               2     19
#  1        16          7               2      7
#  2        10          2               7      1
#  3        14          4               8      2
#  4        13          6               3      4
#  ...     ...        ...             ...    ...
#  4394      3          3               0      0
#  4395      3          3               0      0
#  4396      4          4               0      0
#  4397      5          5               0      0
#  4398      4          4               0      0
#
#  [4399 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0     I'm just saying, I can see why the 'brief'case...  2.111111   0.260579
#  1     He insisted on a contract no longer than one p...  2.090909   0.284590
#  2                 We're only allowed one carry on item.  2.000000   0.269680
#  3                Don't ask me. I'm just the middle man.  2.000000   0.269680
#  4                                   It's a merger case.  2.000000   0.288675
#  ...                                                 ...       ...        ...
#  4136  Look, Mr. Cruz said he wanted our campaign con...  1.000000   0.408248
#  4137  Next time can't we just mail a check to the Su...  1.000000   0.408248
#  4138  What Bernie doesn't realize--these year-end bo...  1.000000   0.408248
#  4139  It took me years to move up to middle management.  1.000000   0.408248
#  4140  It's "the briefcase." With the nuclear launch ...  1.000000   0.408248
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0         9          2               4      3
#  1        11          4               2      5
#  2        11          4               3      4
#  3        11          4               3      4
#  4         9          3               3      3
#  ...     ...        ...             ...    ...
#  4136      3          3               0      0
#  4137      3          3               0      0
#  4138      3          3               0      0
#  4139      3          3               0      0
#  4140      3          3               0      0
#
#  [4141 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0                                       No, you grow up  1.940860   0.058149
#  1     Sheriff, I feel like we're just going through ...  1.918605   0.053714
#  2     We're losing them! They're gaining on us! We'r...  1.907143   0.068680
#  3     Sometimes I feel like we're just going through...  1.900000   0.058886
#  4                       I think they're toying with us.  1.881481   0.065708
#  ...                                                 ...       ...        ...
#  3946                No , they are not thoroughbreds ...  1.000000   0.095346
#  3947  It’s no use — the Law’s got cross-country ski ...  1.000000   0.087039
#  3948     To think I gave up collecting stamps for this.  1.000000   0.095346
#  3949                  Last one home is a rotten rocker!  1.000000   0.095346
#  3950                 Hobbie faster, there gaining on us  1.000000   0.095346
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0       186         64              69     53
#  1       172         50              86     36
#  2       140         53              47     40
#  3       150         47              71     32
#  4       135         48              55     32
#  ...     ...        ...             ...    ...
#  3946     11         11               0      0
#  3947     12         12               0      0
#  3948     11         11               0      0
#  3949     11         11               0      0
#  3950     11         11               0      0
#
#  [3951 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0            Tell me about your childhood very quickly.  2.000000   0.141220
#  1        I think that’s all the time we have for today.  1.904762   0.194015
#  2                  Looks like our time is up for today.  1.888889   0.178755
#  3     I'm afraid I'm still going to have to bill you...  1.888889   0.159429
#  4     Let's not forget what happened the last time o...  1.888889   0.196187
#  ...                                                 ...       ...        ...
#  4265  Now that we have Obamacare we can live where w...  1.000000   0.288675
#  4266  In an overreaching effort to fully empathize, ...  1.000000   0.707107
#  4267  Brighto! Brighto! It makes old bodies new. We'...  1.000000   0.223607
#  4268           Don't worry; we're on the E train track.  1.000000   0.288675
#  4269  Is this really the only way I can get my thera...  1.000000   0.288675
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0        27          7              13      7
#  1        21          9               5      7
#  2        18          6               8      4
#  3        18          5              10      3
#  4        18          7               6      5
#  ...     ...        ...             ...    ...
#  4265      4          4               0      0
#  4266      2          2               0      0
#  4267      5          5               0      0
#  4268      4          4               0      0
#  4269      4          4               0      0
#
#  [4270 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0     I have no concrete plans for the rest of the day.  2.095238   0.194015
#  1     I told my ex I'll take her back if she drops s...  2.055556   0.189119
#  2             Don't worry, I will take it to the grave.  2.000000   0.218218
#  3                 You better give me the short version.  2.000000   0.218218
#  4                                     Duck?! For lunch?  2.000000   0.169031
#  ...                                                 ...       ...        ...
#  5913         They promised a counter offer before noon.  1.000000   0.408248
#  5914   I think you ought to cut short your lunch break.  1.000000   0.408248
#  5915                    THERE GOES THE AIRCONDITIONING.  1.000000   0.288675
#  5916                              The Bronze Plan. Why?  1.000000   0.408248
#  5917  Sounds good. But at this restaurant its called...  1.000000   0.408248
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0        21          7               5      9
#  1        18          5               7      6
#  2        15          5               5      5
#  3        15          5               5      5
#  4        15          3               9      3
#  ...     ...        ...             ...    ...
#  5913      3          3               0      0
#  5914      3          3               0      0
#  5915      4          4               0      0
#  5916      3          3               0      0
#  5917      3          3               0      0
#
#  [5918 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0     Who'd have thought they'd get you for tax evas...  2.391304   0.174898
#  1     It's probably unethical for me to say this, bu...  2.388889   0.200308
#  2     Just don't laugh when they talk about the deat...  2.277778   0.210905
#  3     Stop it. They'll just keep bringing in a new j...  2.250000   0.214087
#  4        It looked like you convinced the older jurors.  2.214286   0.238553
#  ...                                                 ...       ...        ...
#  7777  No, we could not find one juror who had not ex...  1.000000   0.408248
#  7778  I'd advise against asking the judge whether yo...  1.000000   0.288675
#  7779  I have a sure-fire closing argument that has w...  1.000000   0.707107
#  7780  The whole innocent until proven guilty thing w...  1.000000   0.707107
#  7781              Yes, of course, my fee is negotiable.  1.000000   0.707107
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0        23          5               4     14
#  1        18          4               3     11
#  2        18          5               3     10
#  3        16          4               4      8
#  4        14          4               3      7
#  ...     ...        ...             ...    ...
#  7777      3          3               0      0
#  7778      4          4               0      0
#  7779      2          2               0      0
#  7780      2          2               0      0
#  7781      2          2               0      0
#
#  [7782 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0     This saddest part is he's going in the wrong d...  1.790179   0.051238
#  1     It's annoying until the vultures land. Then it...  1.786026   0.053691
#  2                   Let it go, Dad—it’s just a quarter.  1.748603   0.058136
#  3     Isn't this the same guy who got shipwrecked in...  1.747475   0.077775
#  4                          That's Lawrence of Suburbia.  1.732484   0.061543
#  ...                                                 ...       ...        ...
#  4504  Apparently he's preparing for the next season ...  1.000000   0.074125
#  4505   Your in luck, an oasis is just over the horizon.  1.000000   0.064550
#  4506  He raised me to believe that nature is neither...  1.000000   0.069007
#  4507                The VR water isn't very wet either.  1.000000   0.069007
#  4508  Hank's got the advertising account for our new...  1.000000   0.074125
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0       224         94              83     47
#  1       229        105              68     56
#  2       179         82              60     37
#  3        99         45              34     20
#  4       157         73              53     31
#  ...     ...        ...             ...    ...
#  4504     14         14               0      0
#  4505     16         16               0      0
#  4506     15         15               0      0
#  4507     15         15               0      0
#  4508     14         14               0      0
#
#  [4509 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0     He's pro-gun, but I like his stance on migration.  1.914773   0.060227
#  1                 Now that's what I call riding shotgun  1.906250   0.060655
#  2     We might be empty nesters sooner than we thought.  1.881119   0.063925
#  3                    It must be great to be endangered.  1.878981   0.068434
#  4                             Mockingbird, pretty sure.  1.868421   0.066457
#  ...                                                 ...       ...        ...
#  4609                               Not a friend in need  1.000000   0.095346
#  4610        It likes guns, so it must be a Bernie Bird.  1.000000   0.095346
#  4611  That one looks like he is a few bullets shy of...  1.000000   0.095346
#  4612                                                 aa  1.000000   0.087039
#  4613           Gentrification must have hit Ralph hard.  1.000000   0.074125
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0       176         64              63     49
#  1       160         55              65     40
#  2       143         51              58     34
#  3       157         68              40     49
#  4       152         62              48     42
#  ...     ...        ...             ...    ...
#  4609     11         11               0      0
#  4610     11         11               0      0
#  4611     11         11               0      0
#  4612     12         12               0      0
#  4613     14         14               0      0
#
#  [4614 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0     I have to ask, do you feel that you could be a...  2.060484   0.027639
#  1     Now that you've opened up, let's talk about wh...  2.048047   0.016587
#  2              It's normal to feel empty after a split.  1.943949   0.028433
#  3     You're right; some of us bruise easier than ot...  1.936170   0.048630
#  4        Would you feel more comfortable on the floor ?  1.926680   0.035743
#  ...                                                 ...       ...        ...
#  6640           You say no one thinks you are appealing?  1.000000   0.069007
#  6641  The issue is too much positive reinforcement f...  1.000000   0.069007
#  6642                 You have to REALLY want to change.  1.000000   0.069007
#  6643  I'm no stranger to the transference game, Mr. ...  1.000000   0.064550
#  6644  What makes you think I'm interested in phallic...  1.000000   0.074125
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0       744        190             319    235
#  1      2227        631             858    738
#  2       785        272             285    228
#  3       235         73             104     58
#  4       491        173             181    137
#  ...     ...        ...             ...    ...
#  6640     15         15               0      0
#  6641     15         15               0      0
#  6642     15         15               0      0
#  6643     16         16               0      0
#  6644     14         14               0      0
#
#  [6645 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0     Go and check if it's still raining. I'll wait ...  2.013430   0.016771
#  1         Well, I thought your mother was joining us...  1.865443   0.031291
#  2                 I thought your mother was joining us.  1.845679   0.037498
#  3                I'm in the Wetness Protection Program.  1.818919   0.041299
#  4                      They said, 'widespread showers.'  1.817647   0.039594
#  ...                                                 ...       ...        ...
#  5171  Do you resist spending money on advertising yo...  1.000000   0.054074
#  5172                   This is my family size umbrella.  1.000000   0.060634
#  5173                                'Uh, you go first.'  1.000000   0.060634
#  5174  Is the color right? What about coverage? I jus...  1.000000   0.057166
#  5175  My insurance guy was giving them as gi.......h...  1.000000   0.060634
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0      1936        514             882    540
#  1       654        259             224    171
#  2       486        209             143    134
#  3       370        156             125     89
#  4       340        127             148     65
#  ...     ...        ...             ...    ...
#  5171     19         19               0      0
#  5172     17         17               0      0
#  5173     17         17               0      0
#  5174     18         18               0      0
#  5175     17         17               0      0
#
#  [5176 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0      Have you tried turning it off and back on again?  1.897308   0.011681
#  1     Yes sir, a martini for you and a screwdriver f...  1.796319   0.015741
#  2                        Do you still need a hand, Sir?  1.757093   0.020251
#  3     Yes, my license says I'm an organ donor....why...  1.740981   0.019898
#  4     the mrs. requests you come upstairs and try cr...  1.737998   0.022257
#  ...                                                 ...       ...        ...
#  4742  Dinner is served, sir. Do you want to go upsta...  1.000000   0.026669
#  4743                Shouldn't our steaks be free-range?  1.000000   0.027400
#  4744  I think I should not use the brain of the man ...  1.000000   0.028989
#  4745  Will your guest be joining you for dinner or d...  1.000000   0.028172
#  4746  Sorry sir, but your Mum, the Countess, would l...  1.000000   0.028172
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0      4197       1439            1750   1008
#  1      2445       1040             863    542
#  2      1445        646             504    295
#  3      1386        606             533    247
#  4      1229        577             397    255
#  ...     ...        ...             ...    ...
#  4742     38         38               0      0
#  4743     37         37               0      0
#  4744     35         35               0      0
#  4745     36         36               0      0
#  4746     36         36               0      0
#
#  [4747 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0                    You ordered from the wrong Amazon.  1.891150   0.016696
#  1     Then maybe you should just tell me what you wa...  1.818599   0.027217
#  2              I think I ordered from the wrong Amazon.  1.809836   0.033138
#  3     I don't mind the monkey see as much as the mon...  1.765993   0.031723
#  4     I'll tell you what could be more fun--a barrel...  1.756238   0.034263
#  ...                                                 ...       ...        ...
#  4184                       This is a really chimp date.  1.000000   0.035093
#  4185  This isn't exactly what I had in mind when I s...  1.000000   0.036370
#  4186       There was a volume discount at the pet shop.  1.000000   0.036370
#  4187  Harangueatans? I wish you would enunciate prop...  1.000000   0.036370
#  4188  I would have gone bananas if you would have be...  1.000000   0.037743
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0      2260        848             810    602
#  1       871        374             281    216
#  2       610        273             180    157
#  3       594        263             207    124
#  4       521        238             172    111
#  ...     ...        ...             ...    ...
#  4184     29         29               0      0
#  4185     28         28               0      0
#  4186     28         28               0      0
#  4187     28         28               0      0
#  4188     27         27               0      0
#
#  [4189 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0           Take the picture, dammit, take the picture!  1.747222   0.042551
#  1                 If I don't kill you the smoking will.  1.699531   0.050415
#  2                Remember, it’s ‘Touché!’ not ‘Flambé!’  1.664894   0.055397
#  3       This seems to be a case of reptile dysfunction.  1.660793   0.052030
#  4                 Are you licensed to carry small arms?  1.659722   0.044360
#  ...                                                 ...       ...        ...
#  3958                                    Smile, Hillary!  1.000000   0.037743
#  3959  Humor me Xantho. Sharpen my knife for our barb...  1.000000   0.033903
#  3960  You better have brought your best, overgrown l...  1.000000   0.033903
#  3961  "Whatcha gonna do about it?" saids the armor g...  1.000000   0.033903
#  3962  Well, I gave you the sword to be fair. Now tha...  1.000000   0.033903
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0       360        174             103     83
#  1       213         99              79     35
#  2       188         96              59     33
#  3       227        121              62     44
#  4       288        147              92     49
#  ...     ...        ...             ...    ...
#  3958     27         27               0      0
#  3959     30         30               0      0
#  3960     30         30               0      0
#  3961     30         30               0      0
#  3962     30         30               0      0
#
#  [3963 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0                           Hey! My eyes are down here.  1.791908   0.063108
#  1                           It autocorrected to "hula".  1.762238   0.071537
#  2               Excuse me, Miss, my eyes are down here.  1.761905   0.066415
#  3              Good Samaritan? I was a GREAT Samaritan.  1.761589   0.061410
#  4                                My eyes are down here.  1.736486   0.069380
#  ...                                                 ...       ...        ...
#  4880  I really thought angels don't have gender but ...  1.000000   0.028172
#  4881    i didn't know you could sing in heaven brother.  1.000000   0.028172
#  4882           Don't know, even the saints' are smaller  1.000000   0.028989
#  4883                  I'm always imagining it's bigger.  1.000000   0.028172
#  4884  There's nothing I can do. He can't stop eating...  1.000000   0.028172
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0       173         81              47     45
#  1       143         73              31     39
#  2       147         69              44     34
#  3       151         65              57     29
#  4       148         77              33     38
#  ...     ...        ...             ...    ...
#  4880     36         36               0      0
#  4881     36         36               0      0
#  4882     35         35               0      0
#  4883     36         36               0      0
#  4884     36         36               0      0
#
#  [4885 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0     Well, your profile pic doesn't look much like ...  1.765714   0.059938
#  1                        You voted ‘Leave,’ didn’t you?  1.760000   0.068004
#  2                 Well, I never believed in you either.  1.720779   0.068013
#  3     We have observed you in the barn. So many ques...  1.706767   0.073779
#  4                    Greetings, and let go of my penis.  1.669118   0.074576
#  ...                                                 ...       ...        ...
#  4596  Howdy! Something tells me you're not in Jupite...  1.000000   0.027400
#  4597  I learned from "My Space" about your area's 'o...  1.000000   0.027400
#  4598              Come in. We have delicious apple pie.  1.000000   0.028172
#  4599  I can do zero to sixty in this baby before you...  1.000000   0.027400
#  4600              Escape now. The planet is filling up.  1.000000   0.027400
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0       175         80              56     39
#  1       150         74              38     38
#  2       154         82              33     39
#  3       133         73              26     34
#  4       136         81              19     36
#  ...     ...        ...             ...    ...
#  4596     37         37               0      0
#  4597     37         37               0      0
#  4598     36         36               0      0
#  4599     37         37               0      0
#  4600     37         37               0      0
#
#  [4601 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0                           Welcome to Weight Watchers!  1.642857   0.131203
#  1     We're here today to discuss firing the architect.  1.625000   0.105536
#  2                 This meeting is getting away from me.  1.621622   0.136182
#  3     I am entertaining a motion to evacuate. Do I h...  1.619048   0.117822
#  4     The captain assures me it was a very small ice...  1.589744   0.125753
#  ...                                                 ...       ...        ...
#  4440  Don't worry things are going to go smoothly be...  1.000000   0.057166
#  4441  No need to tell you that its an uphill battle ...  1.000000   0.064550
#  4442             We've deregulated the conference room.  1.000000   0.057166
#  4443  While you might find my position untenable, wa...  1.000000   0.064550
#  4444  Yes, now that you mention it, I suppose I coul...  1.000000   0.054074
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0        42         25               7     10
#  1        40         19              17      4
#  2        37         22               7      8
#  3        42         23              12      7
#  4        39         23               9      7
#  ...     ...        ...             ...    ...
#  4440     18         18               0      0
#  4441     16         16               0      0
#  4442     18         18               0      0
#  4443     16         16               0      0
#  4444     19         19               0      0
#
#  [4445 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0     Of course I understand the gravity of the situ...  1.872832   0.062222
#  1     It's easy once you realize there's nothing to it.  1.843373   0.062773
#  2                         There's really nothing to it.  1.820513   0.062672
#  3                                  I'm virtually there.  1.808219   0.064704
#  4                  Can't stop now, i'm virtually there.  1.787097   0.060709
#  ...                                                 ...       ...        ...
#  4478         Look out below! I lost my grip on the bar.  1.000000   0.030773
#  4479     What? They wouldn't let me bring my big truck.  1.000000   0.029854
#  4480             Juno, schmuno even you can scale this.  1.000000   0.029854
#  4481  As he proved the mountain exists, the old man ...  1.000000   0.030773
#  4482  Seconds earlier, Barney had said to his climbi...  1.000000   0.029854
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0       173         70              55     48
#  1       166         69              54     43
#  2       156         64              56     36
#  3       146         61              52     33
#  4       155         64              60     31
#  ...     ...        ...             ...    ...
#  4478     33         33               0      0
#  4479     34         34               0      0
#  4480     34         34               0      0
#  4481     33         33               0      0
#  4482     34         34               0      0
#
#  [4483 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0                   Your overhead is going to kill you.  1.824176   0.048067
#  1     The consensus of your wise men is: move the ch...  1.767544   0.050632
#  2     According to the doctor, your longevity would ...  1.763636   0.048152
#  3             And the king lived happily severed after.  1.722513   0.055627
#  4     What's long and sharp and will make your nephe...  1.718750   0.054472
#  ...                                                 ...       ...        ...
#  3424                              King Solomon I am not  1.000000   0.024693
#  3425  Your largest campaign contributor is paying $3...  1.000000   0.025318
#  3426  A man named Damocles would like to hunt in you...  1.000000   0.027400
#  3427  Make a note, squire, and let it be heard throu...  1.000000   0.025976
#  3428  You must not move from the throne for one week...  1.000000   0.024098
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0       273        114              93     66
#  1       228         99              83     46
#  2       220         88              96     36
#  3       191         90              64     37
#  4       192         89              68     35
#  ...     ...        ...             ...    ...
#  3424     41         41               0      0
#  3425     40         40               0      0
#  3426     37         37               0      0
#  3427     39         39               0      0
#  3428     42         42               0      0
#
#  [3429 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0          Let's stay in tonight. It's a zoo out there.  2.173155   0.021548
#  1     Sorry I'm late. I hit every traffic light comi...  2.172894   0.010985
#  2     If he's elected, we're going to have a tough t...  1.858867   0.025415
#  3           What happened to us? We used to be so wild.  1.858790   0.023507
#  4     Yes, it's hot. But a ceiling fan will only mak...  1.855787   0.024827
#  ...                                                 ...       ...        ...
#  4072  Come on let us change the sports Chanel and wa...  1.000000   0.014815
#  4073  What are you watching?" "The Giraffe news, on ...  1.000000   0.014599
#  4074     These home movies just don't look right in HD.  1.000000   0.014815
#  4075                            Let's start a movement.  1.000000   0.014815
#  4076  Still watch TV? It's time to go to cook for ou...  1.000000   0.014815
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0      1721        564             295    862
#  1      5246       1285            1769   2192
#  2      1077        461             307    309
#  3      1041        383             422    236
#  4      1054        429             348    277
#  ...     ...        ...             ...    ...
#  4072     68         68               0      0
#  4073     69         69               0      0
#  4074     68         68               0      0
#  4075     68         68               0      0
#  4076     68         68               0      0
#
#  [4077 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0                                 Who's endangered now?  1.682216   0.029492
#  1              They were never going to find you anyway  1.601677   0.035011
#  2                                Sorry...I was texting.  1.589912   0.036228
#  3     Yeah, well your profile wasn't exactly honest ...  1.583333   0.034779
#  4     I'd like to settle this without involving my i...  1.514793   0.037762
#  ...                                                 ...       ...        ...
#  5774  A candid moment: probable origin of Mobia (the...  1.000000   0.012121
#  5775                          Oops! I'm beached, Man...  1.000000   0.012121
#  5776  Would you like to try our new high-mileage oil...  1.000000   0.012121
#  5777  Hey, readers: Get over it. Sometimes shit happ...  1.000000   0.012121
#  5778                                         Uh, bumpy.  1.000000   0.012121
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0       686        348             208    130
#  1       477        272             123     82
#  2       456        268             107     81
#  3       444        250             129     65
#  4       338        203              96     39
#  ...     ...        ...             ...    ...
#  5774     83         83               0      0
#  5775     83         83               0      0
#  5776     83         83               0      0
#  5777     83         83               0      0
#  5778     83         83               0      0
#
#  [5779 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0                  If you see something, say something.  1.932790   0.041621
#  1                  Our chef trained at the Paris Metro.  1.791096   0.046819
#  2     Sorry for the wait, but it's been like Grand C...  1.766667   0.048988
#  3                          Before this I was a bus-boy.  1.764045   0.050082
#  4     I can arrange a violinist for 25¢. For $1, I c...  1.751938   0.050054
#  ...                                                 ...       ...        ...
#  5000                   So it shouldn't be a total loss.  1.000000   0.021507
#  5001  May I suggest the delectable 'Locomotive Hambu...  1.000000   0.021979
#  5002  Not crazy about the fake dining tables as secu...  1.000000   0.021979
#  5003                        We'll start with the soup !  1.000000   0.021979
#  5004                                    Heads or tails?  1.000000   0.021979
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0       491        226              72    193
#  1       292        130              93     69
#  2       270        126              81     63
#  3       267        128              74     65
#  4       258        123              76     59
#  ...     ...        ...             ...    ...
#  5000     47         47               0      0
#  5001     46         46               0      0
#  5002     46         46               0      0
#  5003     46         46               0      0
#  5004     46         46               0      0
#
#  [5005 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0     Looks like Sammy wins the "bring your pet to w...  1.831960   0.035626
#  1                            Anywhere but Eve's office.  1.803774   0.036209
#  2     We're searching for rats that escaped from the...  1.735000   0.045877
#  3          Looks like you ordered from the wrong Amazon  1.730077   0.039430
#  4                    Speak softly and carry a big fish.  1.723958   0.043378
#  ...                                                 ...       ...        ...
#  4290  So then, what you're saying is, he don't want ...  1.000000   0.017095
#  4291  We.re ordering lunch.. The cafeterias is only ...  1.000000   0.016807
#  4292                            May I suggest the 5:15?  1.000000   0.017095
#  4293  We are out of the C, may I offer you an A runn...  1.000000   0.017095
#  4294                           Hey guys here's dinner..  1.000000   0.017095
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0       607        293             123    191
#  1       530        246             142    142
#  2       400        235              36    129
#  3       389        184             126     79
#  4       384        206              78    100
#  ...     ...        ...             ...    ...
#  4290     59         59               0      0
#  4291     60         60               0      0
#  4292     59         59               0      0
#  4293     59         59               0      0
#  4294     59         59               0      0
#
#  [4295 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0                                You and your surfaris.  2.017933   0.028650
#  1     I just couldn't 'catch and release because who...  1.870130   0.039082
#  2     Of course I knew I was marrying a mermaid. I j...  1.859375   0.037802
#  3     I'll bet that last restaurant will never have ...  1.828125   0.042737
#  4     Yes, I love him. I'll always love him. I'm jus...  1.821510   0.041115
#  ...                                                 ...       ...        ...
#  6098  It really was a whale of a good time! I hope w...  1.000000   0.019048
#  6099                   Whale, should we go back or not?  1.000000   0.019048
#  6100  I've got a whale of a tale to tell ya, a whale...  1.000000   0.018692
#  6101  Two tourists bundled a newborn baby whale into...  1.000000   0.018692
#  6102  Ho Hum. Another traffic jam. Good thing we are...  1.000000   0.019048
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0      1171        552              46    573
#  1       539        261              87    191
#  2       512        228             128    156
#  3       448        228              69    151
#  4       437        207             101    129
#  ...     ...        ...             ...    ...
#  6098     53         53               0      0
#  6099     53         53               0      0
#  6100     54         54               0      0
#  6101     54         54               0      0
#  6102     53         53               0      0
#
#  [6103 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0              Sometimes a dipstick is just a dipstick.  2.262050   0.017781
#  1     The impotence, that feeling of being out of co...  1.819923   0.058789
#  2      I'd like to see you again in two thousand miles.  1.801619   0.050877
#  3     I'm afraid we're out of time, but I'd like to ...  1.737624   0.056387
#  4                    And was this your first breakdown?  1.721649   0.055413
#  ...                                                 ...       ...        ...
#  6594           Why is everyone always fighting over me?  1.000000   0.024098
#  6595  His name was Harlan Sanders,and he could get m...  1.000000   0.023531
#  6596       We need to work on your inferiority complex.  1.000000   0.024098
#  6597               The old little dog is still a puppy.  1.000000   0.024098
#  6598  I thought I was so smart but she really didn't...  1.000000   0.024098
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0      2614        827             275   1512
#  1       261        145              18     98
#  2       247        108              80     59
#  3       202         98              59     45
#  4       194         92              64     38
#  ...     ...        ...             ...    ...
#  6594     42         42               0      0
#  6595     43         43               0      0
#  6596     42         42               0      0
#  6597     42         42               0      0
#  6598     42         42               0      0
#
#  [6599 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0                            He said the patent expired  1.792929   0.027907
#  1     He says the guy with the original idea never t...  1.729958   0.032407
#  2          He is making a life preserver for my Mother.  1.726879   0.031130
#  3      I hope he discovers fire soon. Dinner is at six.  1.726879   0.029896
#  4                   He told me that the patent expired.  1.710938   0.033228
#  ...                                                 ...       ...        ...
#  5554  Aunt Sally and Martha the Next door neighbor w...  1.012821   0.012903
#  5555              I solved his compulsion months ago...  1.012821   0.012903
#  5556       Self lounging car beats having a lazy honey.  1.012821   0.012903
#  5557                        Henry's the same roll-over.  1.000000   0.013245
#  5558  It's his little counter-protest. They've got t...  1.000000   0.013245
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0       990        505             185    300
#  1       711        387             129    195
#  2       692        352             177    163
#  3       692        334             213    145
#  4       640        345             135    160
#  ...     ...        ...             ...    ...
#  5554     78         77               1      0
#  5555     78         77               1      0
#  5556     78         77               1      0
#  5557     76         76               0      0
#  5558     76         76               0      0
#
#  [5559 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0                             I'm not a big cat person.  1.968226   0.019539
#  1     Think it over. I'm still the only one here who...  1.953709   0.019240
#  2     In my defense, the neutering was a requirement...  1.785781   0.023712
#  3     First of all, I'd like to apologize for the wh...  1.775776   0.024933
#  4     I may be a little prick, but at least I'm not ...  1.759341   0.027648
#  ...                                                 ...       ...        ...
#  3099  Since he retired, he keeps saying he'll get ar...  1.000000   0.012739
#  3100  Naming him Michelangelo may have been a slight...  1.000000   0.012739
#  3101  Listen, MacPherson! Touch not the cat bot a gl...  1.000000   0.012739
#  3102  Don't be so sure that "Time for some traffic p...  1.000000   0.012739
#  3103           I just thought you could spare a square.  1.000000   0.012739
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0      1731        600             586    545
#  1      1685        566             631    488
#  2      1069        460             378    231
#  3       999        447             329    223
#  4       910        452             225    233
#  ...     ...        ...             ...    ...
#  3099     79         79               0      0
#  3100     79         79               0      0
# ...
#  1      2330       1063             694    573
#  2      1489        678             493    318
#  3      2859       1512             629    718
#  4      1396        685             439    272
#  ...     ...        ...             ...    ...
#  4767     80         78               2      0
#  4768     65         64               1      0
#  4769     75         74               1      0
#  4770     71         71               0      0
#  4771     60         60               0      0
#
#  [4772 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0     Four wishes if you listen to a timeshare prese...  1.640625   0.016212
#  1     Your wish may be granted within three to five ...  1.601240   0.023435
#  2      You wished for a better candidate, so here I am!  1.599327   0.047854
#  3     All our genies are busy right now, but please ...  1.597238   0.018721
#  4        Wish granted, kid, pending corporate approval.  1.587747   0.020564
#  ...                                                 ...       ...        ...
#  4246  Ginie You Are late for the work Please grant E...  1.020408   0.020620
#  4247  For freeing me, I shall grant you three free a...  1.017241   0.017392
#  4248  Boy next door: I want to be a writer! Genie: Y...  1.000000   0.021979
#  4249                     Some things never change . . .  1.000000   0.024693
#  4250  Lukey Boy... It may not indeed really 'Look th...  1.000000   0.023531
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0      2368       1315             589    464
#  1       968        527             300    141
#  2       297        184              48     65
#  3      1738       1020             398    320
#  4      1567        975             263    329
#  ...     ...        ...             ...    ...
#  4246     49         48               1      0
#  4247     58         57               1      0
#  4248     46         46               0      0
#  4249     41         41               0      0
#  4250     43         43               0      0
#
#  [4251 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0     You know, it's gonna itch like hell when it gr...  1.644131   0.022626
#  1                                           Gesundheit!  1.627457   0.013957
#  2                        Did I get rid of your hiccups?  1.617814   0.018955
#  3         With all due respect, you look like a pickle.  1.612998   0.018176
#  4                                 Helluva sneeze, Merv.  1.610350   0.017215
#  ...                                                 ...       ...        ...
#  4529             Is it spikey in here or it is just me?  1.014706   0.014815
#  4530  When you feel like a prick, but you're just no...  1.013699   0.013793
#  4531        You should check out that new website Hims.  1.013699   0.013793
#  4532  Hey at least you don’t have to pay for waxing ...  1.013158   0.013245
#  4533  going to target to get a Stanley cup was not a...  1.010526   0.010582
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0      1065        547             350    168
#  1      3154       1775             779    600
#  2      1583        868             452    263
#  3      1708        940             489    279
#  4      1971       1109             521    341
#  ...     ...        ...             ...    ...
#  4529     68         67               1      0
#  4530     73         72               1      0
#  4531     73         72               1      0
#  4532     76         75               1      0
#  4533     95         94               1      0
#
#  [4534 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0                You say ‘flood’ like it’s a bad thing.  1.754483   0.010607
#  1                     Why don’t we just meet you there?  1.754386   0.024555
#  2                   You took us out of school for this?  1.747109   0.015671
#  3      Don’t tell me you already have two talking fish.  1.745729   0.020769
#  4     Being on cedar planks makes us really uncomfor...  1.733796   0.015930
#  ...                                                 ...       ...        ...
#  6319              Couldn't you have found a blonde one?  1.028571   0.028571
#  6320  A  flood. Dreat!  We can visit our family in K...  1.025641   0.018013
#  6321                     We were just feelin' left out!  1.024390   0.017140
#  6322           Spare the water and the fish will spoil.  1.023529   0.016538
#  6323  Fish: "Hey, it's really dry around here. Don't...  1.021739   0.015287
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0      5633       2646            1724   1263
#  1      1026        474             330    222
#  2      2681       1307             745    629
#  3      1522        742             425    355
#  4      2592       1289             704    599
#  ...     ...        ...             ...    ...
#  6319     70         69               0      1
#  6320     78         76               2      0
#  6321     82         80               2      0
#  6322     85         83               2      0
#  6323     92         90               2      0
#
#  [6324 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0                     You never told me you have a sun.  1.833804   0.017922
#  1          Then, of course, there's the age difference.  1.781065   0.014946
#  2     You could have mentioned that those photos wer...  1.768243   0.013896
#  3     What do you mean your last relationship ended ...  1.766927   0.028997
#  4     Of course I’ve been seeing other galaxies—I’m ...  1.723093   0.014388
#  ...                                                 ...       ...        ...
#  6982                 Take me with you" - Guy Interrupte  1.000000   0.013606
#  6983  What part of the term universal is so troublin...  1.000000   0.018349
#  6984        holy cow!And I thought an African is Black.  1.000000   0.015268
#  6985  Here comes the Sun, doo-dee-doo-wah, and it's ...  1.000000   0.018019
#  6986  What’s wrong babe? You’ve barely touched your ...  1.000000   0.017700
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0      2124        930             617    577
#  1      2873       1305             892    676
#  2      3426       1622             976    828
#  3       768        358             231    179
#  4      2936       1411             927    598
#  ...     ...        ...             ...    ...
#  6982     74         74               0      0
#  6983     55         55               0      0
#  6984     66         66               0      0
#  6985     56         56               0      0
#  6986     57         57               0      0
#
#  [6987 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0              Sorry, only the catcher works from home.  1.751036   0.015100
#  1                  Yes, I did order a slider for lunch.  1.745735   0.015739
#  2                        Just give me ballpark figures.  1.721150   0.015416
#  3     Can you explain why your last employer said yo...  1.708984   0.014347
#  4     The job requires short, intense periods of pro...  1.691736   0.016268
#  ...                                                 ...       ...        ...
#  5154  We're looking for pitchers of our products, no...  1.012195   0.012270
#  5155  Now listen up, Hargrove! You see that target o...  1.010204   0.010257
#  5156  I'm thinking of ending everything. It's been s...  1.010101   0.010152
#  5157  Ok, the pitch is You were a Mound Star. Got an...  1.000000   0.009756
#  5158  I call it the 'Curveball Strategy' – guarantee...  1.000000   0.008889
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0      2896       1406             805    685
#  1      2462       1143             802    517
#  2      2331       1061             859    411
#  3      3072       1548             870    654
#  4      2287       1153             686    448
#  ...     ...        ...             ...    ...
#  5154     82         81               1      0
#  5155     98         97               1      0
#  5156     99         98               1      0
#  5157    103        103               0      0
#  5158    113        113               0      0
#
#  [5159 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0     Yes, it's called Thesaurus, but you're not rel...  1.789508   0.014872
#  1     And the comet missed the earth, and all the di...  1.770942   0.013653
#  2     Now, now…it’s just an eclipse. Mass extinction...  1.747782   0.016292
#  3     It's called evolution and you're not going to ...  1.715789   0.015469
#  4     No, I'm not reading the asteroid part again. Y...  1.703360   0.015063
#  ...                                                 ...       ...        ...
#  5183                 What did you bring home this time?  1.035714   0.020370
#  5184  I’ve already told you, this one is too scary f...  1.035714   0.026491
#  5185  and the knight on his white horse slayed the d...  1.034483   0.019676
#  5186  Yes, we could watch it, but I believe the book...  1.033333   0.019028
#  5187  Stop sniffing me… I already told you that it w...  1.028986   0.020345
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0      3050       1417             858    775
#  1      3462       1604            1047    811
#  2      2367       1117             730    520
#  3      2565       1255             784    526
#  4      2589       1258             841    490
#  ...     ...        ...             ...    ...
#  5183     84         81               3      0
#  5184     84         82               1      1
#  5185     87         84               3      0
#  5186     90         87               3      0
#  5187     69         67               2      0
#
#  [5188 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0                The seller isn't willing to come down.  1.793467   0.010272
#  1     According to the Trump organization, it's 30,0...  1.777523   0.011315
#  2             The other prospective buyer fell through.  1.749795   0.009337
#  3             The owner moved back in with his parents.  1.735524   0.009608
#  4        You asked to see something in your price range  1.733046   0.019221
#  ...                                                 ...       ...        ...
#  5508  It's above the flood plain. Trust me, it's a s...  1.039604   0.019503
#  5509  I told you the price of houses make tree house...  1.038462   0.021915
#  5510  We want to turn it into an Airbnb.  It will ta...  1.035294   0.020133
#  5511                 Well, there goes the neighborhood.  1.032967   0.018821
#  5512  I know what you're thinking, but when you leav...  1.031579   0.018037
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0      5970       2624            1955   1391
#  1      5668       2827            1275   1566
#  2      7326       3485            2189   1652
#  3      6511       3045            2143   1323
#  4      1622        760             535    327
#  ...     ...        ...             ...    ...
#  5508    101         97               4      0
#  5509     78         75               3      0
#  5510     85         82               3      0
#  5511     91         88               3      0
#  5512     95         92               3      0
#
#  [5513 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0                 See how the nose seems to follow you?  1.677551   0.019807
#  1     It’s like a New Yorker cartoon. You have to pr...  1.661285   0.014937
#  2     Ever since I can remember, paintings of childr...  1.650282   0.017831
#  3                            Any Bozo could paint that.  1.648699   0.019321
#  4     You throw a pie, it’s a joke. You throw paint,...  1.627878   0.013584
#  ...                                                 ...       ...        ...
#  6152  Is that Barnum or Bailey?  We can  just  take ...  1.012658   0.012739
#  6153  It's okay, Bozo. Just spending a little time w...  1.012658   0.012739
#  6154                  My face has more color than this.  1.012500   0.012579
#  6155  Why’ve you turned up wearing your suit with 4 ...  1.011765   0.011835
#  6156  Note the artist’s brilliant use of the color o...  1.000000   0.014599
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0      1470        737             470    263
#  1      2911       1605             687    619
#  2      1953       1067             502    384
#  3      1614        869             443    302
#  4      3257       1810             849    598
#  ...     ...        ...             ...    ...
#  6152     79         78               1      0
#  6153     79         78               1      0
#  6154     80         79               1      0
#  6155     85         84               1      0
#  6156     69         69               0      0
#
#  [6157 rows x 7 columns],
#                                                  caption      mean  precision  \
#  rank
#  0     Do you think death rays would be considered el...  1.632287   0.012004
#  1                       Oh sure, now you look at a map.  1.632171   0.018294
#  2                   I've never heard of planet fitness.  1.626694   0.017874
#  3     Wait, was it "conquer the mall" or "conquer th...  1.624266   0.020087
#  4                             To Bed, Bath, and Beyond!  1.620504   0.013953
#  ...                                                 ...       ...        ...
#  4953  Looks like we took a wrong turn at the Hubble ...  1.023256   0.016347
#  4954             Post-modern just doesn't do it for me.  1.022222   0.015625
#  4955  How was I supposed to know they covered themse...  1.020833   0.014654
#  4956  No, they wanted us to teleport the giveaway ca...  1.020619   0.020619
#  4957  The cinema is still here, but they aren’t play...  1.012195   0.012270
#
#        votes  not_funny  somewhat_funny  funny
#  rank
#  0      4014       2170            1150    694
#  1      1778        976             480    322
#  2      1918       1079             476    363
#  3      1533        870             369    294
#  4      2975       1640             824    511
#  ...     ...        ...             ...    ...
#  4953     86         84               2      0
#  4954     90         88               2      0
#  4955     96         94               2      0
#  4956     97         96               0      1
#  4957     82         81               1      0
#
#  [4958 rows x 7 columns]]

# %% [markdown]
# # How to use, load and save plots

# %% [markdown]
# In the new folder _gui there are (for now) 3 files: gui.py, plots_gui.py and plots_gui.pkl
#
# 1. gui.py - here is all the layout for a fancy GUI interface for fast and comfortable plot visualisatiopn
# 2. plot_gui.py - here is a class that allows to easy "build" plots from an existing template. Its also necessary to have this class so all plots are manipulated in the same way(displayed, load and saved). Can be improved in any moment to better track plots(eg: make an attribute "categories")
# 3. plots_gui.pkl - containt all loaded plots. The save function of PlotsGUI has a anti-duplicate test, but it tests only titles. This allows us to make sure that plots are unique, but also allows us to easely download a plot list, update it and save it back.

# %%
import sys

sys.path.append("../_gui")  # go up one level, then into _gui

from plots_gui import PlotGUI
import plots_gui as pg
# Out:
# /Users/43rt1k/Documents/EPFL/_MASTER/ADA/ADAcore42/dom_analysis/../_gui/plots_gui.py:75: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ## Creating a plot

# %%
def _plot1 (ax):
    # Compute contest-level stats
    x = [len(df) for df in dataA]              # total captions per contest
    y = [df["votes"].sum() for df in dataA]    # total votes per contest
    ax.scatter(x, y, alpha=0.7, color='skyblue', edgecolor='black')
    return ax



plot1 = PlotGUI(title="Contest Size vs. Total Votes", 
            xlabel="Number of Captions per Contest", 
            ylabel="Total Votes per Contest")
plot1.set_define_plot(_plot1)

# %% [markdown]
# ## Display a plot

# %%
plot1.show()

# %% [markdown]
# ## Store plots

# %%
plots = [plot1] # list of plots to save

PlotGUI.save_plots(plots)
# Out:
# 💾 Saved 1 total plots to /Users/43rt1k/Documents/EPFL/_MASTER/ADA/ADAcore42/_gui/plots_gui.pkl
# ℹ️ No new plots were added (all already present).

# %% [markdown]
# No redundant plot added

# %%
import copy
plots.append(copy.copy(plot1))

PlotGUI.save_plots(plots)
# Out:
# 💾 Saved 1 total plots to /Users/43rt1k/Documents/EPFL/_MASTER/ADA/ADAcore42/_gui/plots_gui.pkl
# ℹ️ No new plots were added (all already present).

# %% [markdown]
# ### Load plots

# %%
plots = PlotGUI.load_plots()
# Out:
# ✅ Loaded 1 plots from /Users/43rt1k/Documents/EPFL/_MASTER/ADA/ADAcore42/_gui/plots_gui.pkl

# %%
plots[0].show()
plots
# Out:
# /Users/43rt1k/Documents/EPFL/_MASTER/ADA/ADAcore42/dom_analysis/../_gui/plots_gui.py:75: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
